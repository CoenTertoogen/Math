# %%
import pandas as pd
import statsmodels.formula.api as sm

# %%
df = pd.read_csv('dataset_1654342.csv')
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       06/08/2023         17:41:54              1.0
# 1               2       06/10/2023         11:30:46              2.0
# 2               3       06/06/2023         09:19:26              3.0
# 3               4       06/10/2023         17:25:49              1.0
# 4               5       06/05/2023         14:55:12              1.0
#
#    store_id store_location  unit_price product_category   product_type
# 0         2      Groningen        3.25              Tea       Chai tea
# 1         2      Groningen        4.50        Chocolate  Hot chocolate
# 2         2      Groningen        3.00              Tea      Black tea
# 3         3          Breda        4.50        Chocolate  Hot chocolate
# 4         1      Amsterdam        4.50        Chocolate  Hot chocolate

# %%
product_category_dummies = pd.get_dummies(df['product_category'])

# %%
df_product_category_dummies = pd.concat([df,product_category_dummies],axis=1)

# %%
df_product_category_dummies.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       06/08/2023         17:41:54              1.0
# 1               2       06/10/2023         11:30:46              2.0
# 2               3       06/06/2023         09:19:26              3.0
# 3               4       06/10/2023         17:25:49              1.0
# 4               5       06/05/2023         14:55:12              1.0
#
#    store_id store_location  unit_price product_category   product_type  \
# 0         2      Groningen        3.25              Tea       Chai tea
# 1         2      Groningen        4.50        Chocolate  Hot chocolate
# 2         2      Groningen        3.00              Tea      Black tea
# 3         3          Breda        4.50        Chocolate  Hot chocolate
# 4         1      Amsterdam        4.50        Chocolate  Hot chocolate
#
#    Bakery  Chocolate  Coffee    Tea
# 0   False      False   False   True
# 1   False       True   False  False
# 2   False      False   False   True
# 3   False       True   False  False
# 4   False       True   False  False

# %%
model1 = sm.ols('Bakery ~ Chocolate + Coffee + Tea',data = df_product_category_dummies).fit()
print(model1.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model1 = sm.ols('Bakery ~ Chocolate + Coffee + Tea',data = df_product_category_dummies).fit()
#       2 print(model1.summary())
#
# File ~/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:209, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     206 max_endog = cls._formula_max_endog
#     207 if (max_endog is not None and
#     208         endog.ndim > 1 and endog.shape[1] > max_endog):
# --> 209     raise ValueError('endog has evaluated to an array with multiple '
#     210                      'columns that has shape {0}. This occurs when '
#     211                      'the variable converted to endog is non-numeric'
#     212                      ' (e.g., bool or str).'.format(endog.shape))
#     213 if drop_cols is not None and len(drop_cols) > 0:
#     214     cols = [x for x in exog.columns if x not in drop_cols]
#
# ValueError: endog has evaluated to an array with multiple columns that has shape (7488, 2). This occurs when the variable converted to endog is non-numeric (e.g., bool or str).
